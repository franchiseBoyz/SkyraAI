# %%
# !pip install requests yfinance azure-eventhub pandas requests azure-data-tables azure-kusto-data azure-kusto-ingest
# !pip install --upgrade azure-identity azure-core azure-kusto-data azure-kusto-ingest
# Out:
# StatementMeta(, 8803a690-7a36-4a3f-8053-ad48cbf30914, 9, Finished, Available, Finished)
# Requirement already satisfied: requests in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (2.32.3)
# Requirement already satisfied: yfinance in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (0.2.55)
# Requirement already satisfied: azure-eventhub in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (5.14.0)
# Requirement already satisfied: pandas in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (2.1.4)
# Requirement already satisfied: azure-data-tables in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (12.6.0)
# Requirement already satisfied: azure-kusto-data in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (5.0.2)
# Requirement already satisfied: azure-kusto-ingest in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (5.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests) (2024.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: multitasking>=0.0.7 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from yfinance) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: azure-core>=1.27.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-eventhub) (1.33.0)
# Requirement already satisfied: typing-extensions>=4.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-eventhub) (4.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: yarl>=1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-data-tables) (1.9.3)
# Requirement already satisfied: isodate>=0.6.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-data-tables) (0.6.1)
# Requirement already satisfied: azure-identity<2,>=1.21.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-kusto-data) (1.21.0)
# Requirement already satisfied: msal<2,>=1.9.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-kusto-data) (1.32.0)
# Requirement already satisfied: ijson~=3.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-kusto-data) (3.3.0)
# Requirement already satisfied: azure-storage-blob<13,>=12 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-kusto-ingest) (12.22.0)
# Requirement already satisfied: azure-storage-queue<13,>=12 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-kusto-ingest) (12.12.0)
# Requirement already satisfied: tenacity>=8.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-kusto-ingest) (8.2.3)
# Requirement already satisfied: six>=1.11.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-core>=1.27.0->azure-eventhub) (1.16.0)
# Requirement already satisfied: cryptography>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-identity<2,>=1.21.0->azure-kusto-data) (42.0.2)
# Requirement already satisfied: msal-extensions>=1.2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-identity<2,>=1.21.0->azure-kusto-data) (1.3.1)
# Requirement already satisfied: soupsieve>1.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal<2,>=1.9.0->azure-kusto-data) (2.4.0)
# Requirement already satisfied: multidict>=4.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from yarl>=1.0->azure-data-tables) (6.0.4)
# Requirement already satisfied: cffi>=1.12 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from cryptography>=2.5->azure-identity<2,>=1.21.0->azure-kusto-data) (1.16.0)
# Requirement already satisfied: pycparser in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity<2,>=1.21.0->azure-kusto-data) (2.21)
# Requirement already satisfied: azure-identity in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (1.21.0)
# Requirement already satisfied: azure-core in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (1.33.0)
# Requirement already satisfied: azure-kusto-data in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (5.0.2)
# Requirement already satisfied: azure-kusto-ingest in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (5.0.2)
# Requirement already satisfied: cryptography>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-identity) (42.0.2)
# Requirement already satisfied: msal>=1.30.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-identity) (1.32.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-identity) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-identity) (4.9.0)
# Requirement already satisfied: requests>=2.21.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-core) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-core) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-kusto-data) (2.8.2)
# Requirement already satisfied: ijson~=3.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-kusto-data) (3.3.0)
# Requirement already satisfied: azure-storage-blob<13,>=12 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-kusto-ingest) (12.22.0)
# Requirement already satisfied: azure-storage-queue<13,>=12 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-kusto-ingest) (12.12.0)
# Requirement already satisfied: tenacity>=8.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-kusto-ingest) (8.2.3)
# Requirement already satisfied: isodate>=0.6.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-storage-blob<13,>=12->azure-kusto-ingest) (0.6.1)
# Requirement already satisfied: cffi>=1.12 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from cryptography>=2.5->azure-identity) (1.16.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity) (2.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.21.0->azure-core) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.21.0->azure-core) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.21.0->azure-core) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.21.0->azure-core) (2024.2.2)
# Requirement already satisfied: pycparser in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity) (2.21)

# %%
import json
import requests
import pandas as pd
import time
import logging

from datetime import datetime
from azure.eventhub import EventHubProducerClient, EventData
from azure.storage.filedatalake import DataLakeServiceClient
from concurrent.futures import ThreadPoolExecutor

from azureml.core import Workspace
from azureml.core.keyvault import Keyvault
# Out:
# StatementMeta(, 8803a690-7a36-4a3f-8053-ad48cbf30914, 10, Finished, Available, Finished)

# %%
# ENVIRONMENT CONFIGURATIONS
ws = Workspace.from_config()
key_vault = ws.get_default_keyvault()
secret_value = key_vault.get_secret("my-secret-name")
api_key = key_vault.get_secret("api_key")
conn_string = key_vault.get_secret("conn_string")


# Configuration
API_KEY = api_key
EVENT_HUB_CONN_STR = conn_string
MAX_WORKERS = 5
DAYS_HISTORY = 100
REQUEST_TIMEOUT = 15

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.StreamHandler(),
        logging.FileHandler('formatted_financial_pipeline.log')
    ]
)
logger = logging.getLogger(__name__)

def fetch_ticker_data(ticker: str) -> list:
    """Fetch stock data with proper error handling"""
    url = "https://api.financialdatasets.ai/prices/"
    params = {
        "ticker": ticker,
        "interval": "day",
        "interval_multiplier": 1,
        "start_date": (datetime.utcnow() - timedelta(days=DAYS_HISTORY)).strftime('%Y-%m-%d'),
        "end_date": datetime.utcnow().strftime('%Y-%m-%d')
    }
    
    headers = {
        "X-API-KEY": API_KEY,
        "Accept": "application/json"
    }
    
    try:
        response = requests.get(
            url,
            headers=headers,
            params=params,
            timeout=REQUEST_TIMEOUT
        )
        response.raise_for_status()
        
        data = response.json()
        if isinstance(data, dict) and 'prices' in data:
            return data['prices']
        return data if isinstance(data, list) else []
        
    except requests.exceptions.RequestException as e:
        logger.error(f"Request failed for {ticker}: {str(e)}")
    except Exception as e:
        logger.error(f"Unexpected error fetching {ticker}: {str(e)}")
    
    return []

def format_record(record: dict, ticker: str) -> dict:
    """Format data to match your exact requirements"""
    try:
        # Calculate daily change if not provided
        daily_change = (float(record['close']) - float(record['open'])) if 'close' in record and 'open' in record else 0
        
        return {
            "ticker": ticker,
            "price": float(record.get('close', 0)),
            "timestamp": record.get('time', datetime.utcnow().isoformat()),
            "volume": int(record.get('volume', 0)),
            "open": float(record.get('open', 0)),
            "high": float(record.get('high', 0)),
            "low": float(record.get('low', 0)),
            "change": round(daily_change, 2),
            "EventProcessedUtcTime": datetime.utcnow().isoformat() + "Z",
            "PartitionId": str(hash(ticker) % 4),  # Distribute across partitions
            "EventEnqueuedUtcTime": datetime.utcnow().isoformat() + "Z"
        }
    except Exception as e:
        logger.error(f"Formatting error for {ticker}: {str(e)}")
        return None

def process_ticker(ticker: str) -> list:
    """Process all records for a single ticker"""
    logger.info(f"Processing {ticker}")
    records = fetch_ticker_data(ticker)
    return [format_record(r, ticker) for r in records if format_record(r, ticker) is not None]

def send_to_event_hub(records: list) -> bool:
    """Send formatted records to Event Hub"""
    if not records:
        return False
    
    producer = None
    try:
        producer = EventHubProducerClient.from_connection_string(
            EVENT_HUB_CONN_STR,
            retry_total=3
        )
        
        with producer:
            batch = producer.create_batch()
            for record in records:
                try:
                    batch.add(EventData(json.dumps(record).encode('utf-8')))
                except ValueError:
                    # Batch full, send and create new
                    producer.send_batch(batch)
                    batch = producer.create_batch()
                    batch.add(EventData(json.dumps(record).encode('utf-8')))
            
            if len(batch) > 0:
                producer.send_batch(batch)
                logger.info(f"Sent {len(batch)} records")
                return True
            
            return False
            
    except Exception as e:
        logger.error(f"Event Hub send failed: {str(e)}")
        return False
    finally:
        if producer:
            producer.close()

def main():
    """Main execution with parallel processing"""
    logger.info("Starting formatted financial pipeline")
    start_time = time.time()
    
    try:
        # Process tickers in parallel
        with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
            results = list(executor.map(process_ticker, TICKERS))
        
        # Flatten results
        all_records = [r for sublist in results for r in sublist]
        
        if all_records:
            success = send_to_event_hub(all_records)
            logger.info(f"Pipeline {'succeeded' if success else 'failed'}. Processed {len(all_records)} records")
        else:
            logger.warning("No records processed")
            
    except Exception as e:
        logger.error(f"Pipeline failed: {str(e)}")
    finally:
        logger.info(f"Execution time: {time.time() - start_time:.2f}s")

if __name__ == "__main__":
    main()
# Out:
# StatementMeta(, 8803a690-7a36-4a3f-8053-ad48cbf30914, 11, Finished, Available, Finished)
# 2025-04-08 23:48:18,789 - INFO - Starting formatted financial pipeline
# 2025-04-08 23:48:18,798 - INFO - Processing AAPL
# 2025-04-08 23:48:18,800 - INFO - Processing MSFT
# 2025-04-08 23:48:18,800 - INFO - Processing GOOGL
# 2025-04-08 23:48:18,801 - INFO - Processing TSLA
# 2025-04-08 23:48:18,802 - INFO - Processing NVDA
# 2025-04-08 23:48:21,081 - INFO - Connection state changed: None -> <ConnectionState.START: 0>
# 2025-04-08 23:48:21,521 - INFO - Connection state changed: <ConnectionState.START: 0> -> <ConnectionState.HDR_SENT: 2>
# 2025-04-08 23:48:21,522 - INFO - Connection state changed: <ConnectionState.HDR_SENT: 2> -> <ConnectionState.HDR_SENT: 2>
# 2025-04-08 23:48:21,522 - INFO - Connection state changed: <ConnectionState.HDR_SENT: 2> -> <ConnectionState.OPEN_PIPE: 4>
# 2025-04-08 23:48:21,523 - INFO - Session state changed: <SessionState.UNMAPPED: 0> -> <SessionState.BEGIN_SENT: 1>
# 2025-04-08 23:48:21,524 - INFO - Link state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:21,524 - INFO - Management link receiver state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:21,526 - INFO - Link state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:21,526 - INFO - Management link sender state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:21,777 - INFO - Connection state changed: <ConnectionState.OPEN_PIPE: 4> -> <ConnectionState.OPEN_SENT: 7>
# 2025-04-08 23:48:21,828 - INFO - Connection state changed: <ConnectionState.OPEN_SENT: 7> -> <ConnectionState.OPENED: 9>
# 2025-04-08 23:48:21,879 - INFO - Session state changed: <SessionState.BEGIN_SENT: 1> -> <SessionState.MAPPED: 3>
# 2025-04-08 23:48:21,930 - INFO - Link state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:21,930 - INFO - Management link receiver state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:21,981 - INFO - Link state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:21,982 - INFO - Management link sender state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:22,353 - INFO - Link state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:22,604 - INFO - Link state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:22,868 - INFO - An error occurred when detaching the link: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:22,869 - INFO - Link state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:22,869 - INFO - An error occurred when detaching the link: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:22,869 - INFO - Link state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:22,870 - INFO - Management link receiver state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:22,870 - INFO - An error occurred when detaching the link: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:22,870 - INFO - Link state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:22,871 - INFO - Management link sender state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:22,871 - INFO - An error occurred when ending the session: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:22,871 - INFO - Session state changed: <SessionState.MAPPED: 3> -> <SessionState.UNMAPPED: 0>
# 2025-04-08 23:48:22,872 - INFO - An error occurred when closing the connection: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:22,872 - INFO - Connection state changed: <ConnectionState.OPENED: 9> -> <ConnectionState.END: 13>
# 2025-04-08 23:48:23,672 - INFO - 'EHProducer-459833d7-d488-47b7-9bf6-dadd3f8da80d' has an exception (ConnectError('Can not send frame out due to exception: The write operation timed out\nError condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')). Retrying...
# 2025-04-08 23:48:24,404 - INFO - Connection state changed: None -> <ConnectionState.START: 0>
# 2025-04-08 23:48:24,846 - INFO - Connection state changed: <ConnectionState.START: 0> -> <ConnectionState.HDR_SENT: 2>
# 2025-04-08 23:48:24,847 - INFO - Connection state changed: <ConnectionState.HDR_SENT: 2> -> <ConnectionState.HDR_SENT: 2>
# 2025-04-08 23:48:24,847 - INFO - Connection state changed: <ConnectionState.HDR_SENT: 2> -> <ConnectionState.OPEN_PIPE: 4>
# 2025-04-08 23:48:24,848 - INFO - Session state changed: <SessionState.UNMAPPED: 0> -> <SessionState.BEGIN_SENT: 1>
# 2025-04-08 23:48:24,849 - INFO - Link state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:24,849 - INFO - Management link receiver state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:24,850 - INFO - Link state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:24,850 - INFO - Management link sender state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:25,101 - INFO - Connection state changed: <ConnectionState.OPEN_PIPE: 4> -> <ConnectionState.OPEN_SENT: 7>
# 2025-04-08 23:48:25,152 - INFO - Connection state changed: <ConnectionState.OPEN_SENT: 7> -> <ConnectionState.OPENED: 9>
# 2025-04-08 23:48:25,202 - INFO - Session state changed: <SessionState.BEGIN_SENT: 1> -> <SessionState.MAPPED: 3>
# 2025-04-08 23:48:25,253 - INFO - Link state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:25,254 - INFO - Management link receiver state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:25,305 - INFO - Link state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:25,305 - INFO - Management link sender state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:25,678 - INFO - Link state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:25,929 - INFO - Link state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:26,181 - INFO - An error occurred when detaching the link: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:26,182 - INFO - Link state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:26,182 - INFO - An error occurred when detaching the link: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:26,183 - INFO - Link state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:26,183 - INFO - Management link receiver state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:26,184 - INFO - An error occurred when detaching the link: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:26,184 - INFO - Link state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:26,184 - INFO - Management link sender state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:26,185 - INFO - An error occurred when ending the session: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:26,186 - INFO - Session state changed: <SessionState.MAPPED: 3> -> <SessionState.UNMAPPED: 0>
# 2025-04-08 23:48:26,186 - INFO - An error occurred when closing the connection: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:26,186 - INFO - Connection state changed: <ConnectionState.OPENED: 9> -> <ConnectionState.END: 13>
# 2025-04-08 23:48:27,787 - INFO - 'EHProducer-459833d7-d488-47b7-9bf6-dadd3f8da80d' has an exception (ConnectError('Can not send frame out due to exception: The write operation timed out\nError condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')). Retrying...
# 2025-04-08 23:48:28,479 - INFO - Connection state changed: None -> <ConnectionState.START: 0>
# 2025-04-08 23:48:28,920 - INFO - Connection state changed: <ConnectionState.START: 0> -> <ConnectionState.HDR_SENT: 2>
# 2025-04-08 23:48:28,921 - INFO - Connection state changed: <ConnectionState.HDR_SENT: 2> -> <ConnectionState.HDR_SENT: 2>
# 2025-04-08 23:48:28,921 - INFO - Connection state changed: <ConnectionState.HDR_SENT: 2> -> <ConnectionState.OPEN_PIPE: 4>
# 2025-04-08 23:48:28,922 - INFO - Session state changed: <SessionState.UNMAPPED: 0> -> <SessionState.BEGIN_SENT: 1>
# 2025-04-08 23:48:28,923 - INFO - Link state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:28,923 - INFO - Management link receiver state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:28,924 - INFO - Link state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:28,924 - INFO - Management link sender state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:29,175 - INFO - Connection state changed: <ConnectionState.OPEN_PIPE: 4> -> <ConnectionState.OPEN_SENT: 7>
# 2025-04-08 23:48:29,226 - INFO - Connection state changed: <ConnectionState.OPEN_SENT: 7> -> <ConnectionState.OPENED: 9>
# 2025-04-08 23:48:29,277 - INFO - Session state changed: <SessionState.BEGIN_SENT: 1> -> <SessionState.MAPPED: 3>
# 2025-04-08 23:48:29,327 - INFO - Link state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:29,328 - INFO - Management link receiver state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:29,379 - INFO - Link state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:29,379 - INFO - Management link sender state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:29,751 - INFO - Link state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:30,002 - INFO - Link state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:30,254 - INFO - An error occurred when detaching the link: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:30,257 - INFO - Link state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:30,257 - INFO - An error occurred when detaching the link: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:30,258 - INFO - Link state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:30,258 - INFO - Management link receiver state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:30,258 - INFO - An error occurred when detaching the link: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:30,259 - INFO - Link state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:30,259 - INFO - Management link sender state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:30,259 - INFO - An error occurred when ending the session: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:30,260 - INFO - Session state changed: <SessionState.MAPPED: 3> -> <SessionState.UNMAPPED: 0>
# 2025-04-08 23:48:30,261 - INFO - An error occurred when closing the connection: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:30,261 - INFO - Connection state changed: <ConnectionState.OPENED: 9> -> <ConnectionState.END: 13>
# 2025-04-08 23:48:33,461 - INFO - 'EHProducer-459833d7-d488-47b7-9bf6-dadd3f8da80d' has an exception (ConnectError('Can not send frame out due to exception: The write operation timed out\nError condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')). Retrying...
# 2025-04-08 23:48:34,207 - INFO - Connection state changed: None -> <ConnectionState.START: 0>
# 2025-04-08 23:48:34,658 - INFO - Connection state changed: <ConnectionState.START: 0> -> <ConnectionState.HDR_SENT: 2>
# 2025-04-08 23:48:34,659 - INFO - Connection state changed: <ConnectionState.HDR_SENT: 2> -> <ConnectionState.HDR_SENT: 2>
# 2025-04-08 23:48:34,660 - INFO - Connection state changed: <ConnectionState.HDR_SENT: 2> -> <ConnectionState.OPEN_PIPE: 4>
# 2025-04-08 23:48:34,660 - INFO - Session state changed: <SessionState.UNMAPPED: 0> -> <SessionState.BEGIN_SENT: 1>
# 2025-04-08 23:48:34,661 - INFO - Link state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:34,661 - INFO - Management link receiver state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:34,662 - INFO - Link state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:34,662 - INFO - Management link sender state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:34,913 - INFO - Connection state changed: <ConnectionState.OPEN_PIPE: 4> -> <ConnectionState.OPEN_SENT: 7>
# 2025-04-08 23:48:34,964 - INFO - Connection state changed: <ConnectionState.OPEN_SENT: 7> -> <ConnectionState.OPENED: 9>
# 2025-04-08 23:48:35,014 - INFO - Session state changed: <SessionState.BEGIN_SENT: 1> -> <SessionState.MAPPED: 3>
# 2025-04-08 23:48:35,065 - INFO - Link state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:35,066 - INFO - Management link receiver state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:35,117 - INFO - Link state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:35,117 - INFO - Management link sender state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:35,494 - INFO - Link state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:35,745 - INFO - Link state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:35,998 - INFO - An error occurred when detaching the link: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:35,998 - INFO - Link state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:35,999 - INFO - An error occurred when detaching the link: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:35,999 - INFO - Link state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:36,000 - INFO - Management link receiver state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:36,000 - INFO - An error occurred when detaching the link: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:36,001 - INFO - Link state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:36,001 - INFO - Management link sender state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:36,001 - INFO - An error occurred when ending the session: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:36,001 - INFO - Session state changed: <SessionState.MAPPED: 3> -> <SessionState.UNMAPPED: 0>
# 2025-04-08 23:48:36,002 - INFO - An error occurred when closing the connection: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:36,002 - INFO - Connection state changed: <ConnectionState.OPENED: 9> -> <ConnectionState.END: 13>
# 2025-04-08 23:48:42,403 - INFO - 'EHProducer-459833d7-d488-47b7-9bf6-dadd3f8da80d' has an exception (ConnectError('Can not send frame out due to exception: The write operation timed out\nError condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')). Retrying...
# 2025-04-08 23:48:42,404 - INFO - 'EHProducer-459833d7-d488-47b7-9bf6-dadd3f8da80d' operation has exhausted retry. Last exception: ConnectError('Can not send frame out due to exception: The write operation timed out\nError condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out').
# 2025-04-08 23:48:43,103 - INFO - Connection state changed: None -> <ConnectionState.START: 0>
# 2025-04-08 23:48:43,547 - INFO - Connection state changed: <ConnectionState.START: 0> -> <ConnectionState.HDR_SENT: 2>
# 2025-04-08 23:48:43,548 - INFO - Connection state changed: <ConnectionState.HDR_SENT: 2> -> <ConnectionState.HDR_SENT: 2>
# 2025-04-08 23:48:43,548 - INFO - Connection state changed: <ConnectionState.HDR_SENT: 2> -> <ConnectionState.OPEN_PIPE: 4>
# 2025-04-08 23:48:43,549 - INFO - Session state changed: <SessionState.UNMAPPED: 0> -> <SessionState.BEGIN_SENT: 1>
# 2025-04-08 23:48:43,550 - INFO - Link state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:43,550 - INFO - Management link receiver state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:43,551 - INFO - Link state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:43,551 - INFO - Management link sender state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:43,802 - INFO - Connection state changed: <ConnectionState.OPEN_PIPE: 4> -> <ConnectionState.OPEN_SENT: 7>
# 2025-04-08 23:48:43,853 - INFO - Connection state changed: <ConnectionState.OPEN_SENT: 7> -> <ConnectionState.OPENED: 9>
# 2025-04-08 23:48:43,903 - INFO - Session state changed: <SessionState.BEGIN_SENT: 1> -> <SessionState.MAPPED: 3>
# 2025-04-08 23:48:43,954 - INFO - Link state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:43,954 - INFO - Management link receiver state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:44,005 - INFO - Link state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:44,006 - INFO - Management link sender state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:44,379 - INFO - Link state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:44,380 - INFO - Management link receiver state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:44,381 - INFO - Link state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:44,381 - INFO - Management link sender state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:44,601 - INFO - Link state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:44,602 - INFO - Management link receiver state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:44,603 - INFO - Link state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:44,603 - INFO - Management link sender state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:44,826 - INFO - Link state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACH_SENT: 4>
# 2025-04-08 23:48:44,827 - INFO - Management link receiver state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACH_SENT: 4>
# 2025-04-08 23:48:44,828 - INFO - Link state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACH_SENT: 4>
# 2025-04-08 23:48:44,828 - INFO - Management link sender state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACH_SENT: 4>
# 2025-04-08 23:48:44,829 - INFO - Link state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACH_SENT: 4>
# 2025-04-08 23:48:44,829 - INFO - Management link sender state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACH_SENT: 4>
# 2025-04-08 23:48:44,830 - INFO - Link state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACH_SENT: 4>
# 2025-04-08 23:48:44,830 - INFO - Management link receiver state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACH_SENT: 4>
# 2025-04-08 23:48:44,830 - INFO - Session state changed: <SessionState.MAPPED: 3> -> <SessionState.END_SENT: 4>
# 2025-04-08 23:48:44,831 - INFO - Connection state changed: <ConnectionState.OPENED: 9> -> <ConnectionState.CLOSE_SENT: 11>
# 2025-04-08 23:48:44,832 - INFO - Connection state changed: <ConnectionState.CLOSE_SENT: 11> -> <ConnectionState.END: 13>
# 2025-04-08 23:48:44,832 - INFO - Session state changed: <SessionState.END_SENT: 4> -> <SessionState.DISCARDING: 6>
# 2025-04-08 23:48:44,832 - INFO - Link state changed: <LinkState.DETACH_SENT: 4> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:44,833 - INFO - Management link sender state changed: <LinkState.DETACH_SENT: 4> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:44,833 - INFO - Link state changed: <LinkState.DETACH_SENT: 4> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:44,833 - INFO - Management link receiver state changed: <LinkState.DETACH_SENT: 4> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:44,834 - INFO - Link state changed: <LinkState.DETACH_SENT: 4> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:44,834 - INFO - Management link sender state changed: <LinkState.DETACH_SENT: 4> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:44,835 - INFO - Link state changed: <LinkState.DETACH_SENT: 4> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:44,836 - INFO - Management link receiver state changed: <LinkState.DETACH_SENT: 4> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:45,764 - INFO - Connection state changed: None -> <ConnectionState.START: 0>
# 2025-04-08 23:48:46,236 - INFO - Connection state changed: <ConnectionState.START: 0> -> <ConnectionState.HDR_SENT: 2>
# 2025-04-08 23:48:46,237 - INFO - Connection state changed: <ConnectionState.HDR_SENT: 2> -> <ConnectionState.HDR_SENT: 2>
# 2025-04-08 23:48:46,238 - INFO - Connection state changed: <ConnectionState.HDR_SENT: 2> -> <ConnectionState.OPEN_PIPE: 4>
# 2025-04-08 23:48:46,238 - INFO - Session state changed: <SessionState.UNMAPPED: 0> -> <SessionState.BEGIN_SENT: 1>
# 2025-04-08 23:48:46,239 - INFO - Link state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:46,239 - INFO - Management link receiver state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:46,240 - INFO - Link state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:46,240 - INFO - Management link sender state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:46,491 - INFO - Connection state changed: <ConnectionState.OPEN_PIPE: 4> -> <ConnectionState.OPEN_SENT: 7>
# 2025-04-08 23:48:46,542 - INFO - Connection state changed: <ConnectionState.OPEN_SENT: 7> -> <ConnectionState.OPENED: 9>
# 2025-04-08 23:48:46,593 - INFO - Session state changed: <SessionState.BEGIN_SENT: 1> -> <SessionState.MAPPED: 3>
# 2025-04-08 23:48:46,644 - INFO - Link state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:46,644 - INFO - Management link receiver state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:46,695 - INFO - Link state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:46,696 - INFO - Management link sender state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:47,069 - INFO - Link state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:47,321 - INFO - Link state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:47,573 - INFO - An error occurred when detaching the link: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:47,574 - INFO - Link state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:47,574 - INFO - An error occurred when detaching the link: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:47,575 - INFO - Link state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:47,575 - INFO - Management link receiver state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:47,575 - INFO - An error occurred when detaching the link: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:47,576 - INFO - Link state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:47,576 - INFO - Management link sender state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:47,577 - INFO - An error occurred when ending the session: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:47,577 - INFO - Session state changed: <SessionState.MAPPED: 3> -> <SessionState.UNMAPPED: 0>
# 2025-04-08 23:48:47,577 - INFO - An error occurred when closing the connection: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:47,578 - INFO - Connection state changed: <ConnectionState.OPENED: 9> -> <ConnectionState.END: 13>
# 2025-04-08 23:48:48,379 - INFO - 'EHProducer-459833d7-d488-47b7-9bf6-dadd3f8da80d' has an exception (ConnectError('Can not send frame out due to exception: The write operation timed out\nError condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')). Retrying...
# 2025-04-08 23:48:49,082 - INFO - Connection state changed: None -> <ConnectionState.START: 0>
# 2025-04-08 23:48:49,530 - INFO - Connection state changed: <ConnectionState.START: 0> -> <ConnectionState.HDR_SENT: 2>
# 2025-04-08 23:48:49,531 - INFO - Connection state changed: <ConnectionState.HDR_SENT: 2> -> <ConnectionState.HDR_SENT: 2>
# 2025-04-08 23:48:49,532 - INFO - Connection state changed: <ConnectionState.HDR_SENT: 2> -> <ConnectionState.OPEN_PIPE: 4>
# 2025-04-08 23:48:49,532 - INFO - Session state changed: <SessionState.UNMAPPED: 0> -> <SessionState.BEGIN_SENT: 1>
# 2025-04-08 23:48:49,533 - INFO - Link state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:49,533 - INFO - Management link receiver state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:49,534 - INFO - Link state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:49,534 - INFO - Management link sender state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:49,785 - INFO - Connection state changed: <ConnectionState.OPEN_PIPE: 4> -> <ConnectionState.OPEN_SENT: 7>
# 2025-04-08 23:48:49,836 - INFO - Connection state changed: <ConnectionState.OPEN_SENT: 7> -> <ConnectionState.OPENED: 9>
# 2025-04-08 23:48:49,887 - INFO - Session state changed: <SessionState.BEGIN_SENT: 1> -> <SessionState.MAPPED: 3>
# 2025-04-08 23:48:49,937 - INFO - Link state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:49,938 - INFO - Management link receiver state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:49,988 - INFO - Link state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:49,989 - INFO - Management link sender state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:50,364 - INFO - Link state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:50,615 - INFO - Link state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:50,867 - INFO - An error occurred when detaching the link: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:50,868 - INFO - Link state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:50,868 - INFO - An error occurred when detaching the link: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:50,869 - INFO - Link state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:50,869 - INFO - Management link receiver state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:50,870 - INFO - An error occurred when detaching the link: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:50,870 - INFO - Link state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:50,871 - INFO - Management link sender state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:50,871 - INFO - An error occurred when ending the session: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:50,871 - INFO - Session state changed: <SessionState.MAPPED: 3> -> <SessionState.UNMAPPED: 0>
# 2025-04-08 23:48:50,872 - INFO - An error occurred when closing the connection: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:50,875 - INFO - Connection state changed: <ConnectionState.OPENED: 9> -> <ConnectionState.END: 13>
# 2025-04-08 23:48:52,475 - INFO - 'EHProducer-459833d7-d488-47b7-9bf6-dadd3f8da80d' has an exception (ConnectError('Can not send frame out due to exception: The write operation timed out\nError condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')). Retrying...
# 2025-04-08 23:48:53,355 - INFO - Connection state changed: None -> <ConnectionState.START: 0>
# 2025-04-08 23:48:53,799 - INFO - Connection state changed: <ConnectionState.START: 0> -> <ConnectionState.HDR_SENT: 2>
# 2025-04-08 23:48:53,800 - INFO - Connection state changed: <ConnectionState.HDR_SENT: 2> -> <ConnectionState.HDR_SENT: 2>
# 2025-04-08 23:48:53,800 - INFO - Connection state changed: <ConnectionState.HDR_SENT: 2> -> <ConnectionState.OPEN_PIPE: 4>
# 2025-04-08 23:48:53,801 - INFO - Session state changed: <SessionState.UNMAPPED: 0> -> <SessionState.BEGIN_SENT: 1>
# 2025-04-08 23:48:53,802 - INFO - Link state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:53,802 - INFO - Management link receiver state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:53,803 - INFO - Link state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:53,803 - INFO - Management link sender state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:54,054 - INFO - Connection state changed: <ConnectionState.OPEN_PIPE: 4> -> <ConnectionState.OPEN_SENT: 7>
# 2025-04-08 23:48:54,105 - INFO - Connection state changed: <ConnectionState.OPEN_SENT: 7> -> <ConnectionState.OPENED: 9>
# 2025-04-08 23:48:54,156 - INFO - Session state changed: <SessionState.BEGIN_SENT: 1> -> <SessionState.MAPPED: 3>
# 2025-04-08 23:48:54,207 - INFO - Link state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:54,207 - INFO - Management link receiver state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:54,258 - INFO - Link state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:54,258 - INFO - Management link sender state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:54,632 - INFO - Link state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:54,883 - INFO - Link state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:55,135 - INFO - An error occurred when detaching the link: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:55,136 - INFO - Link state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:55,136 - INFO - An error occurred when detaching the link: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:55,136 - INFO - Link state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:55,137 - INFO - Management link receiver state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:55,137 - INFO - An error occurred when detaching the link: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:55,138 - INFO - Link state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:55,138 - INFO - Management link sender state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:48:55,139 - INFO - An error occurred when ending the session: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:55,139 - INFO - Session state changed: <SessionState.MAPPED: 3> -> <SessionState.UNMAPPED: 0>
# 2025-04-08 23:48:55,139 - INFO - An error occurred when closing the connection: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:48:55,140 - INFO - Connection state changed: <ConnectionState.OPENED: 9> -> <ConnectionState.END: 13>
# 2025-04-08 23:48:58,340 - INFO - 'EHProducer-459833d7-d488-47b7-9bf6-dadd3f8da80d' has an exception (ConnectError('Can not send frame out due to exception: The write operation timed out\nError condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')). Retrying...
# 2025-04-08 23:48:59,038 - INFO - Connection state changed: None -> <ConnectionState.START: 0>
# 2025-04-08 23:48:59,482 - INFO - Connection state changed: <ConnectionState.START: 0> -> <ConnectionState.HDR_SENT: 2>
# 2025-04-08 23:48:59,483 - INFO - Connection state changed: <ConnectionState.HDR_SENT: 2> -> <ConnectionState.HDR_SENT: 2>
# 2025-04-08 23:48:59,483 - INFO - Connection state changed: <ConnectionState.HDR_SENT: 2> -> <ConnectionState.OPEN_PIPE: 4>
# 2025-04-08 23:48:59,484 - INFO - Session state changed: <SessionState.UNMAPPED: 0> -> <SessionState.BEGIN_SENT: 1>
# 2025-04-08 23:48:59,485 - INFO - Link state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:59,485 - INFO - Management link receiver state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:59,486 - INFO - Link state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:59,486 - INFO - Management link sender state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:48:59,737 - INFO - Connection state changed: <ConnectionState.OPEN_PIPE: 4> -> <ConnectionState.OPEN_SENT: 7>
# 2025-04-08 23:48:59,788 - INFO - Connection state changed: <ConnectionState.OPEN_SENT: 7> -> <ConnectionState.OPENED: 9>
# 2025-04-08 23:48:59,838 - INFO - Session state changed: <SessionState.BEGIN_SENT: 1> -> <SessionState.MAPPED: 3>
# 2025-04-08 23:48:59,889 - INFO - Link state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:59,890 - INFO - Management link receiver state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:59,941 - INFO - Link state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:48:59,941 - INFO - Management link sender state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:49:00,315 - INFO - Link state changed: <LinkState.DETACHED: 0> -> <LinkState.ATTACH_SENT: 1>
# 2025-04-08 23:49:00,566 - INFO - Link state changed: <LinkState.ATTACH_SENT: 1> -> <LinkState.ATTACHED: 3>
# 2025-04-08 23:49:00,818 - INFO - An error occurred when detaching the link: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:49:00,819 - INFO - Link state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:49:00,819 - INFO - An error occurred when detaching the link: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:49:00,820 - INFO - Link state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:49:00,820 - INFO - Management link receiver state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:49:00,821 - INFO - An error occurred when detaching the link: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:49:00,821 - INFO - Link state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:49:00,821 - INFO - Management link sender state changed: <LinkState.ATTACHED: 3> -> <LinkState.DETACHED: 0>
# 2025-04-08 23:49:00,822 - INFO - An error occurred when ending the session: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:49:00,823 - INFO - Session state changed: <SessionState.MAPPED: 3> -> <SessionState.UNMAPPED: 0>
# 2025-04-08 23:49:00,823 - INFO - An error occurred when closing the connection: AMQPConnectionError('Error condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')
# 2025-04-08 23:49:00,823 - INFO - Connection state changed: <ConnectionState.OPENED: 9> -> <ConnectionState.END: 13>
# 2025-04-08 23:49:07,224 - INFO - 'EHProducer-459833d7-d488-47b7-9bf6-dadd3f8da80d' has an exception (ConnectError('Can not send frame out due to exception: The write operation timed out\nError condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out')). Retrying...
# 2025-04-08 23:49:07,224 - INFO - 'EHProducer-459833d7-d488-47b7-9bf6-dadd3f8da80d' operation has exhausted retry. Last exception: ConnectError('Can not send frame out due to exception: The write operation timed out\nError condition: ErrorCondition.SocketError\n Error Description: Can not send frame out due to exception: The write operation timed out').
# 2025-04-08 23:49:07,225 - ERROR - Event Hub send failed: Can not send frame out due to exception: The write operation timed out
# Error condition: ErrorCondition.SocketError
#  Error Description: Can not send frame out due to exception: The write operation timed out
# 2025-04-08 23:49:07,226 - INFO - Pipeline failed. Processed 340 records
# 2025-04-08 23:49:07,226 - INFO - Execution time: 48.44s
